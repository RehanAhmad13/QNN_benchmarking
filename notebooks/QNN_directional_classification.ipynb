# %% [markdown]
# ### Imports

# %%
import yfinance as yf
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
import pennylane.numpy as pnp
import pennylane as qml
from pennylane.optimize import AdamOptimizer

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from pennylane.templates import StronglyEntanglingLayers

# %% [markdown]
# ### Checking Available Tickers

# %%
tickers = [
    "AKBNK.IS", "ARCLK.IS", "DOHOL.IS", "DYHOL.IS", "EREGL.IS", "FINBN.IS", "FORTS.IS",
    "GARAN.IS", "GSDHO.IS", "HURGZ.IS", "ISCTR.IS", "ISGYO.IS", "KCHOL.IS"
]

## -> data range 
start_train = "1998-01-05"
end_test = "2007-08-31"

## downloading
data = yf.download(
    tickers,
    start=start_train,
    end=end_test,
    progress=False
)

# only extracting available data 
available_tickers = []
missing_tickers = []

for ticker in tickers:
    try:
        if not data['Close'][ticker].dropna().empty:
            available_tickers.append(ticker)
        else:
            missing_tickers.append(ticker)
    except KeyError:
        missing_tickers.append(ticker)

available_tickers, missing_tickers
# Out:
# YF.download() has changed argument auto_adjust default to True
# 4 Failed downloads:
# ['FINBN.IS', 'DYHOL.IS']: YFPricesMissingError('possibly delisted; no price data found  (1d 1998-01-05 -> 2007-08-31)')
# ['ISCTR.IS']: YFPricesMissingError('possibly delisted; no price data found  (1d 1998-01-05 -> 2007-08-31) (Yahoo error = "Data doesn\'t exist for startDate = 883951200, endDate = 1188507600")')
# ['FORTS.IS']: HTTPError('HTTP Error 404: ')
# (['AKBNK.IS',
#   'ARCLK.IS',
#   'DOHOL.IS',
#   'EREGL.IS',
#   'GARAN.IS',
#   'GSDHO.IS',
#   'HURGZ.IS',
#   'ISGYO.IS',
#   'KCHOL.IS'],
#  ['DYHOL.IS', 'FINBN.IS', 'FORTS.IS', 'ISCTR.IS'])

# %% [markdown]
# ### Computing Indicators

# %%
def compute_indicators(df):
    df = df.copy()  # don't wanna mess up original

    # moving averages for trend
    df['MA14'] = df['Close'].rolling(14).mean()
    df['MA37'] = df['Close'].rolling(37).mean()

    # stochastic %K and %D
    low14 = df['Low'].rolling(14).min()
    high14 = df['High'].rolling(14).max()
    df['K14'] = 100 * (df['Close'] - low14) / (high14 - low14)
    df['D3'] = df['K14'].rolling(3).mean()

    # RSI
    delta = df['Close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(14).mean()
    avg_loss = loss.rolling(14).mean()
    rs = avg_gain / avg_loss
    df['RSI14'] = 100 - (100 / (1 + rs))

    # direction label (up = 1, else 0)
    df['Direction'] = (df['Close'].diff() > 0).astype(int)

    # just drop the NaNs from all the rolling ops
    return df.dropna()

# %% [markdown]
# ### Hybrid-QNN
#
# Consist of a linear 3-3 layer of pre-processing, a 6 layer QML structure followed by classical MLP.

# %%
def make_hybrid_binary_classifier(feature_dim, n_layers=6, lr=0.2, momentum=0.5):
    """
    Hybrid quantum-classical binary classifier.
    Inputs: feature_dim = number of classical features.
    Uses SGD + MSE, nothing fancy.
    """
    
    dev = qml.device("default.qubit", wires=feature_dim) # we use default.qubit - use lightning.qubit for speedup. 

    #  Defining the quantum circuit QNode - we use torch interface so we can use the torch optimizer
    @qml.qnode(dev, interface="torch")
    def qnode(inputs, weights):
        qml.AngleEmbedding(inputs, wires=range(feature_dim))
        qml.BasicEntanglerLayers(weights, wires=range(feature_dim))
        return [qml.expval(qml.PauliZ(i)) for i in range(feature_dim)]

    # Wraping everything in  Torch layer 
    weight_shapes = {"weights": (n_layers, feature_dim)}
    qlayer = qml.qnn.TorchLayer(qnode, weight_shapes)

    #  We now build the full model using nn.sequential now that we have defined our quantum layer
    # Classical -> Quantum -> Classical -> Sigmoid
    model = nn.Sequential(
        nn.Linear(feature_dim, feature_dim),  # classical prep layer
        qlayer,                               # quantum circuit
        nn.Linear(feature_dim, 1),            # squeeze to 1 output
        nn.Sigmoid()                          # squish to [0,1] for binary
    )

    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum) # to be consistent with the benchmark ANN 

    loss_fn = nn.MSELoss() # again, to be consistent with the benchmark ANN. We did also try BCE but it doesn't really give any appreciable gains. 

    return model, optimizer, loss_fn

# %%
if __name__ == "__main__":
    TICKERS     = available_tickers
    START_TRAIN = "1998-01-05"
    END_TRAIN   = "2005-12-29"
    START_TEST  = "2006-01-06"
    END_TEST    = "2007-08-31"
    FEATURES    = ['RSI14', 'K14', 'D3']

    raw = yf.download(TICKERS, start=START_TRAIN, end=END_TEST, progress=False)
    results = []

    for ticker in TICKERS:
        df = pd.DataFrame({
            'Close':  raw['Close'][ticker],
            'High':   raw['High'][ticker],
            'Low':    raw['Low'][ticker],
            'Volume': raw['Volume'][ticker]
        }).dropna()

        df = compute_indicators(df)  # must add 'Direction' column (0/1)

        # Train/test split
        tr = df.index <= END_TRAIN
        te = df.index >= START_TEST

        X_tr = df.loc[tr, FEATURES].values.astype(np.float32)
        y_tr = df.loc[tr, 'Direction'].values.reshape(-1,1).astype(np.float32)
        X_te = df.loc[te, FEATURES].values.astype(np.float32)
        y_te = df.loc[te, 'Direction'].values.reshape(-1,1).astype(np.float32)

        # Scale
        scaler = MinMaxScaler()
        X_tr = scaler.fit_transform(X_tr).astype(np.float32)
        X_te = scaler.transform(X_te).astype(np.float32)

        # DataLoader
        train_ds = TensorDataset(torch.from_numpy(X_tr), torch.from_numpy(y_tr))
        loader   = DataLoader(train_ds, batch_size=16, shuffle=True)

        # Build model with MSE loss
        feature_dim = X_tr.shape[1]
        model, optimizer, loss_fn = make_hybrid_binary_classifier(
            feature_dim, n_layers=6, lr=0.2, momentum=0.5
        )

        # Train
        epochs = 10000
        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            for xb, yb in loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss  = loss_fn(preds, yb)   # MSE between pred prob and 0/1 label
                loss.backward()
                optimizer.step()
                running_loss += loss.item() * xb.size(0)
            running_loss /= len(loader.dataset)

        # Test
        model.eval()
        with torch.no_grad():
            probs = model(torch.from_numpy(X_te))
        preds = (probs.numpy() > 0.5).astype(int).ravel()
        acc   = accuracy_score(y_te.ravel(), preds)
        print(f"{ticker:7s} → HybridQNN Acc: {acc:.4f}")
        results.append(acc)

    print(f"\nAverage HybridQNN Accuracy: {np.mean(results):.4f}")
# Out:
# AKBNK.IS → HybridQNN Acc: 0.8208
# ARCLK.IS → HybridQNN Acc: 0.7972
# DOHOL.IS → HybridQNN Acc: 0.8208
# EREGL.IS → HybridQNN Acc: 0.5849
# GARAN.IS → HybridQNN Acc: 0.8396
# GSDHO.IS → HybridQNN Acc: 0.8137
# HURGZ.IS → HybridQNN Acc: 0.5896
# ISGYO.IS → HybridQNN Acc: 0.8113
# KCHOL.IS → HybridQNN Acc: 0.5849
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 103
#     101 preds = model(xb)
#     102 loss  = loss_fn(preds, yb)   # MSE between pred prob and 0/1 label
# --> 103 loss.backward()
#     104 optimizer.step()
#     105 running_loss += loss.item() * xb.size(0)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # QNN Classifier
#
# This QNN classifer was made in pennylane. We did use a torch node also. We will give the code for that also.

# %%
class QNN_StronglyEntanglingClassifier:
    def __init__(self, num_layers, num_qubits, learning_rate=0.01, optimizer="Adam"):
        self.num_layers = num_layers
        self.num_qubits = num_qubits
        self.wires = list(range(num_qubits))  # the total number of wires or qubits 
        
        # param = layers × qubits × 3 because 3 params per qubit in each layer)
        self.num_params = num_layers * num_qubits * 3
        
        # init weights randomly 
        self.weights = 0.01 * pnp.random.randn(num_layers, num_qubits, 3)

        # we use adam optimizer for this. when using torch qnode, we do add SGD for proper comparison. 
        if optimizer == "Adam":
            self.optimizer = AdamOptimizer(learning_rate)
        else:
            raise ValueError(f"not supporting {optimizer} for now")

        self.dev = qml.device("lightning.qubit", wires=self.wires)
        self.qnode = qml.QNode(self._circuit, self.dev, interface="autograd")

        self._X = None
        self._Y = None

    def num_parameters(self):
        return self.num_params

    def encode(self, inputs):
        # classical input → angle for RY gate on each wire
        for i, x in enumerate(inputs):
            angle = (x - 0.5) * pnp.pi  # center around 0 - this is important since we use RY
            qml.RY(angle, wires=self.wires[i])

    def _circuit(self, inputs, weights):
        self.encode(inputs)  # angle embedding
        StronglyEntanglingLayers(weights, wires=self.wires)  # provides more expressibility rather 
                                                             # than making a custom ansatz because pennylane 
                                                             # already adds a lot of circuit depth and complexity
        return qml.expval(qml.PauliZ(self.wires[0]))  # measure Z on first qubit

    def predict(self, inputs, weights=None):
        w = self.weights if weights is None else weights
        out = self.qnode(inputs, w)  
        return (out + 1) / 2  # because expectation is between [-1, 1], we scale to [0, 1] for binary

    def binary_cross_entropy(self, preds, labels):
        # manual BCE, with epsilon for stability
        eps = 1e-10
        preds = pnp.clip(preds, eps, 1 - eps)
        return -pnp.mean(labels * pnp.log(preds) + (1 - labels) * pnp.log(1 - preds))

    def cost(self, weights):
        # forward pass over all inputs
        preds = pnp.stack([self.predict(x, weights) for x in self._X])
        return self.binary_cross_entropy(preds, self._Y)

    def train(self, X, Y, epochs=50):
        self._X = pnp.array(X)
        self._Y = pnp.array(Y)
        w = self.weights

        for e in range(1, epochs + 1):
            w, c = self.optimizer.step_and_cost(self.cost, w)
            grad_norm = pnp.linalg.norm(qml.grad(self.cost)(w))
            print(f"Epoch {e:2d} | BCE Loss: {c:.6f} | ∇ norm: {grad_norm:.2e}")

        self.weights = w  # update internal weights

# %%
if __name__ == "__main__":
    TICKERS = available_tickers
    START_TRAIN, END_TRAIN = "1998-01-05", "2005-12-29"
    START_TEST,  END_TEST  = "2006-01-06", "2007-08-31"
    
    FEATURES = ['RSI14','K14','D3']

    raw = yf.download(TICKERS, start=START_TRAIN, end=END_TEST, progress=False)

    results = []
    for ticker in TICKERS:
        df = pd.DataFrame({
            'Close':  raw['Close'][ticker],
            'High':   raw['High'][ticker],
            'Low':    raw['Low'][ticker],
            'Volume': raw['Volume'][ticker]
        }).dropna()
        df = compute_indicators(df)

        tr = df.index <= END_TRAIN
        te = df.index >= START_TEST
        X = df[FEATURES].values
        y = df['Direction'].values

        X_tr, y_tr = X[tr], y[tr]
        X_te, y_te = X[te], y[te]

        scaler = MinMaxScaler()
        X_tr = scaler.fit_transform(X_tr)
        X_te = scaler.transform(X_te)

        qnn = QNN_StronglyEntanglingClassifier(num_layers=3, num_qubits=X_tr.shape[1], learning_rate=0.05)
        qnn.train(X_tr, y_tr, epochs=100)

        probs = [qnn.predict(x) for x in X_te]
        preds = (pnp.array(probs) > 0.5).astype(int).ravel()
        acc   = accuracy_score(y_te, preds)
        print(f"{ticker:7s} → QNN Test accuracy: {acc:.4f}")

        results.append(acc)

    print(f"\nAverage QNN Test Accuracy: {sum(results)/len(results):.4f}")
# Out:
# Epoch  1 | BCE Cost: 1.716128 | ‖grad‖: 1.875e+00
# Epoch  2 | BCE Cost: 1.520598 | ‖grad‖: 1.612e+00
# Epoch  3 | BCE Cost: 1.338164 | ‖grad‖: 1.345e+00
# Epoch  4 | BCE Cost: 1.183580 | ‖grad‖: 1.113e+00
# Epoch  5 | BCE Cost: 1.048444 | ‖grad‖: 8.971e-01
# Epoch  6 | BCE Cost: 0.937682 | ‖grad‖: 7.017e-01
# Epoch  7 | BCE Cost: 0.850962 | ‖grad‖: 5.213e-01
# Epoch  8 | BCE Cost: 0.784265 | ‖grad‖: 3.549e-01
# Epoch  9 | BCE Cost: 0.737001 | ‖grad‖: 2.068e-01
# Epoch 10 | BCE Cost: 0.707949 | ‖grad‖: 8.280e-02
# Epoch 11 | BCE Cost: 0.693996 | ‖grad‖: 5.435e-02
# Epoch 12 | BCE Cost: 0.691396 | ‖grad‖: 1.308e-01
# Epoch 13 | BCE Cost: 0.695925 | ‖grad‖: 1.906e-01
# Epoch 14 | BCE Cost: 0.701710 | ‖grad‖: 2.191e-01
# Epoch 15 | BCE Cost: 0.700757 | ‖grad‖: 1.971e-01
# Epoch 16 | BCE Cost: 0.689592 | ‖grad‖: 1.039e-01
# Epoch 17 | BCE Cost: 0.675134 | ‖grad‖: 8.270e-02
# Epoch 18 | BCE Cost: 0.670891 | ‖grad‖: 2.090e-01
# Epoch 19 | BCE Cost: 0.678215 | ‖grad‖: 2.352e-01
# Epoch 20 | BCE Cost: 0.679296 | ‖grad‖: 1.863e-01
# Epoch 76 | BCE Cost: 0.575855 | ‖grad‖: 5.133e-03
# Epoch 77 | BCE Cost: 0.575802 | ‖grad‖: 5.202e-03
# Epoch 78 | BCE Cost: 0.575753 | ‖grad‖: 5.121e-03
# Epoch 79 | BCE Cost: 0.575708 | ‖grad‖: 4.913e-03
# Epoch 80 | BCE Cost: 0.575662 | ‖grad‖: 4.629e-03
# Epoch 81 | BCE Cost: 0.575617 | ‖grad‖: 4.317e-03
# Epoch 82 | BCE Cost: 0.575572 | ‖grad‖: 4.011e-03
# Epoch 83 | BCE Cost: 0.575529 | ‖grad‖: 3.750e-03
# Epoch 84 | BCE Cost: 0.575489 | ‖grad‖: 3.578e-03
# Epoch 85 | BCE Cost: 0.575454 | ‖grad‖: 3.520e-03
# Epoch 86 | BCE Cost: 0.575423 | ‖grad‖: 3.552e-03
# Epoch 87 | BCE Cost: 0.575397 | ‖grad‖: 3.606e-03
# Epoch 88 | BCE Cost: 0.575373 | ‖grad‖: 3.615e-03
# Epoch 89 | BCE Cost: 0.575350 | ‖grad‖: 3.554e-03
# Epoch 90 | BCE Cost: 0.575327 | ‖grad‖: 3.436e-03
# Epoch 91 | BCE Cost: 0.575304 | ‖grad‖: 3.305e-03
# Epoch 92 | BCE Cost: 0.575282 | ‖grad‖: 3.200e-03
# Epoch 93 | BCE Cost: 0.575261 | ‖grad‖: 3.138e-03
# Epoch 94 | BCE Cost: 0.575241 | ‖grad‖: 3.116e-03
# Epoch 95 | BCE Cost: 0.575223 | ‖grad‖: 3.120e-03
# Epoch 96 | BCE Cost: 0.575207 | ‖grad‖: 3.132e-03
# Epoch 97 | BCE Cost: 0.575191 | ‖grad‖: 3.129e-03
# Epoch 98 | BCE Cost: 0.575176 | ‖grad‖: 3.089e-03
# Epoch 99 | BCE Cost: 0.575160 | ‖grad‖: 3.005e-03
# Epoch 100 | BCE Cost: 0.575145 | ‖grad‖: 2.896e-03
# ARCLK.IS → QNN Test accuracy: 0.7241
# Epoch  1 | BCE Cost: 1.207417 | ‖grad‖: 8.053e-01
# Epoch  2 | BCE Cost: 1.130455 | ‖grad‖: 7.786e-01
# Epoch  3 | BCE Cost: 1.045648 | ‖grad‖: 7.247e-01
# Epoch  4 | BCE Cost: 0.961520 | ‖grad‖: 6.295e-01
# Epoch  5 | BCE Cost: 0.884935 | ‖grad‖: 5.186e-01
# Epoch  6 | BCE Cost: 0.818978 | ‖grad‖: 4.042e-01
# Epoch  7 | BCE Cost: 0.765428 | ‖grad‖: 2.971e-01
# Epoch  8 | BCE Cost: 0.725108 | ‖grad‖: 2.093e-01
# Epoch  9 | BCE Cost: 0.696023 | ‖grad‖: 1.537e-01
# Epoch 10 | BCE Cost: 0.675211 | ‖grad‖: 1.362e-01
# Epoch 11 | BCE Cost: 0.659374 | ‖grad‖: 1.405e-01
# Epoch 12 | BCE Cost: 0.645357 | ‖grad‖: 1.465e-01
# Epoch 13 | BCE Cost: 0.630922 | ‖grad‖: 1.432e-01
# Epoch 53 | BCE Cost: 0.529689 | ‖grad‖: 1.285e-02
# Epoch 54 | BCE Cost: 0.529511 | ‖grad‖: 1.168e-02
# Epoch 55 | BCE Cost: 0.529334 | ‖grad‖: 1.105e-02
# Epoch 56 | BCE Cost: 0.529167 | ‖grad‖: 1.110e-02
# Epoch 57 | BCE Cost: 0.529015 | ‖grad‖: 1.151e-02
# Epoch 58 | BCE Cost: 0.528870 | ‖grad‖: 1.174e-02
# Epoch 59 | BCE Cost: 0.528718 | ‖grad‖: 1.139e-02
# Epoch 60 | BCE Cost: 0.528551 | ‖grad‖: 1.041e-02
# Epoch 61 | BCE Cost: 0.528367 | ‖grad‖: 9.083e-03
# Epoch 62 | BCE Cost: 0.528178 | ‖grad‖: 7.986e-03
# Epoch 63 | BCE Cost: 0.528001 | ‖grad‖: 7.677e-03
# Epoch 64 | BCE Cost: 0.527847 | ‖grad‖: 8.086e-03
# Epoch 65 | BCE Cost: 0.527717 | ‖grad‖: 8.602e-03
# Epoch 66 | BCE Cost: 0.527605 | ‖grad‖: 8.757e-03
# Epoch 67 | BCE Cost: 0.527501 | ‖grad‖: 8.519e-03
# Epoch 68 | BCE Cost: 0.527400 | ‖grad‖: 8.215e-03
# Epoch 69 | BCE Cost: 0.527305 | ‖grad‖: 8.223e-03
# Epoch 70 | BCE Cost: 0.527219 | ‖grad‖: 8.563e-03
# Epoch 71 | BCE Cost: 0.527144 | ‖grad‖: 8.888e-03
# Epoch 72 | BCE Cost: 0.527074 | ‖grad‖: 8.869e-03
# Epoch 73 | BCE Cost: 0.527005 | ‖grad‖: 8.472e-03
# Epoch 74 | BCE Cost: 0.526934 | ‖grad‖: 7.977e-03
# Epoch 75 | BCE Cost: 0.526863 | ‖grad‖: 7.759e-03
# Epoch 76 | BCE Cost: 0.526798 | ‖grad‖: 7.903e-03
# Epoch 77 | BCE Cost: 0.526739 | ‖grad‖: 8.104e-03
# Epoch 78 | BCE Cost: 0.526684 | ‖grad‖: 8.014e-03
# Epoch 79 | BCE Cost: 0.526630 | ‖grad‖: 7.548e-03
# Epoch 80 | BCE Cost: 0.526576 | ‖grad‖: 6.907e-03
# Epoch 81 | BCE Cost: 0.526523 | ‖grad‖: 6.384e-03
# Epoch 82 | BCE Cost: 0.526473 | ‖grad‖: 6.090e-03
# Epoch 83 | BCE Cost: 0.526427 | ‖grad‖: 5.912e-03
# Epoch 84 | BCE Cost: 0.526382 | ‖grad‖: 5.790e-03
# Epoch 85 | BCE Cost: 0.526339 | ‖grad‖: 5.843e-03
# Epoch 86 | BCE Cost: 0.526298 | ‖grad‖: 6.121e-03
# Epoch 87 | BCE Cost: 0.526262 | ‖grad‖: 6.386e-03
# Epoch 88 | BCE Cost: 0.526229 | ‖grad‖: 6.298e-03
# Epoch 89 | BCE Cost: 0.526196 | ‖grad‖: 5.725e-03
# Epoch 90 | BCE Cost: 0.526163 | ‖grad‖: 4.869e-03
# Epoch 91 | BCE Cost: 0.526131 | ‖grad‖: 4.140e-03
# Epoch 69 | BCE Cost: 0.642350 | ‖grad‖: 3.260e-03
# Epoch 70 | BCE Cost: 0.642353 | ‖grad‖: 2.938e-03
# Epoch 71 | BCE Cost: 0.642350 | ‖grad‖: 1.291e-03
# Epoch 72 | BCE Cost: 0.642343 | ‖grad‖: 2.414e-03
# Epoch 73 | BCE Cost: 0.642342 | ‖grad‖: 1.883e-03
# Epoch 74 | BCE Cost: 0.642338 | ‖grad‖: 1.186e-03
# Epoch 75 | BCE Cost: 0.642334 | ‖grad‖: 2.298e-03
# Epoch 76 | BCE Cost: 0.642333 | ‖grad‖: 1.432e-03
# Epoch 77 | BCE Cost: 0.642327 | ‖grad‖: 1.038e-03
# Epoch 78 | BCE Cost: 0.642324 | ‖grad‖: 2.029e-03
# Epoch 79 | BCE Cost: 0.642323 | ‖grad‖: 1.192e-03
# Epoch 80 | BCE Cost: 0.642318 | ‖grad‖: 1.343e-03
# Epoch 81 | BCE Cost: 0.642314 | ‖grad‖: 1.764e-03
# Epoch 82 | BCE Cost: 0.642312 | ‖grad‖: 8.015e-04
# Epoch 83 | BCE Cost: 0.642308 | ‖grad‖: 1.361e-03
# Epoch 84 | BCE Cost: 0.642305 | ‖grad‖: 1.350e-03
# Epoch 85 | BCE Cost: 0.642301 | ‖grad‖: 6.655e-04
# Epoch 86 | BCE Cost: 0.642297 | ‖grad‖: 1.629e-03
# Epoch 87 | BCE Cost: 0.642295 | ‖grad‖: 1.340e-03
# Epoch 88 | BCE Cost: 0.642291 | ‖grad‖: 6.501e-04
# Epoch 89 | BCE Cost: 0.642287 | ‖grad‖: 1.165e-03
# Epoch 90 | BCE Cost: 0.642284 | ‖grad‖: 7.192e-04
# Epoch 91 | BCE Cost: 0.642281 | ‖grad‖: 8.835e-04
# Epoch 92 | BCE Cost: 0.642278 | ‖grad‖: 1.062e-03
# Epoch 93 | BCE Cost: 0.642274 | ‖grad‖: 6.469e-04
# Epoch 94 | BCE Cost: 0.642271 | ‖grad‖: 9.754e-04
# Epoch 95 | BCE Cost: 0.642268 | ‖grad‖: 7.586e-04
# Epoch 96 | BCE Cost: 0.642265 | ‖grad‖: 6.879e-04
# Epoch 97 | BCE Cost: 0.642261 | ‖grad‖: 9.141e-04
# Epoch 98 | BCE Cost: 0.642258 | ‖grad‖: 5.306e-04
# Epoch 99 | BCE Cost: 0.642255 | ‖grad‖: 7.113e-04
# Epoch 100 | BCE Cost: 0.642252 | ‖grad‖: 6.585e-04
# EREGL.IS → QNN Test accuracy: 0.5873
# Epoch  1 | BCE Cost: 1.264313 | ‖grad‖: 7.857e-01
# Epoch  2 | BCE Cost: 1.192827 | ‖grad‖: 8.056e-01
# Epoch  3 | BCE Cost: 1.110543 | ‖grad‖: 7.454e-01
# Epoch  4 | BCE Cost: 1.027501 | ‖grad‖: 6.510e-01
# Epoch  5 | BCE Cost: 0.950421 | ‖grad‖: 5.444e-01
# Epoch  6 | BCE Cost: 0.882503 | ‖grad‖: 4.369e-01
# Epoch 85 | BCE Cost: 0.532783 | ‖grad‖: 9.786e-03
# Epoch 86 | BCE Cost: 0.532667 | ‖grad‖: 9.283e-03
# Epoch 87 | BCE Cost: 0.532560 | ‖grad‖: 9.056e-03
# Epoch 88 | BCE Cost: 0.532459 | ‖grad‖: 8.954e-03
# Epoch 89 | BCE Cost: 0.532362 | ‖grad‖: 8.830e-03
# Epoch 90 | BCE Cost: 0.532267 | ‖grad‖: 8.740e-03
# Epoch 91 | BCE Cost: 0.532175 | ‖grad‖: 8.730e-03
# Epoch 92 | BCE Cost: 0.532086 | ‖grad‖: 8.722e-03
# Epoch 93 | BCE Cost: 0.531998 | ‖grad‖: 8.680e-03
# Epoch 94 | BCE Cost: 0.531914 | ‖grad‖: 8.662e-03
# Epoch 95 | BCE Cost: 0.531835 | ‖grad‖: 8.671e-03
# Epoch 96 | BCE Cost: 0.531763 | ‖grad‖: 8.618e-03
# Epoch 97 | BCE Cost: 0.531693 | ‖grad‖: 8.473e-03
# Epoch 98 | BCE Cost: 0.531626 | ‖grad‖: 8.300e-03
# Epoch 99 | BCE Cost: 0.531563 | ‖grad‖: 8.129e-03
# Epoch 100 | BCE Cost: 0.531502 | ‖grad‖: 7.943e-03
# GARAN.IS → QNN Test accuracy: 0.7736
# Epoch  1 | BCE Cost: 1.283108 | ‖grad‖: 9.023e-01
# Epoch  2 | BCE Cost: 1.197923 | ‖grad‖: 8.723e-01
# Epoch  3 | BCE Cost: 1.106922 | ‖grad‖: 7.981e-01
# Epoch  4 | BCE Cost: 1.018290 | ‖grad‖: 7.112e-01
# Epoch  5 | BCE Cost: 0.935731 | ‖grad‖: 6.186e-01
# Epoch  6 | BCE Cost: 0.860764 | ‖grad‖: 5.173e-01
# Epoch  7 | BCE Cost: 0.795557 | ‖grad‖: 4.144e-01
# Epoch  8 | BCE Cost: 0.741655 | ‖grad‖: 3.202e-01
# Epoch  9 | BCE Cost: 0.698586 | ‖grad‖: 2.425e-01
# Epoch 10 | BCE Cost: 0.665070 | ‖grad‖: 1.873e-01
# Epoch 11 | BCE Cost: 0.638969 | ‖grad‖: 1.548e-01
# Epoch 12 | BCE Cost: 0.617924 | ‖grad‖: 1.372e-01
# Epoch 13 | BCE Cost: 0.600126 | ‖grad‖: 1.259e-01
# Epoch 14 | BCE Cost: 0.584537 | ‖grad‖: 1.147e-01
# Epoch 15 | BCE Cost: 0.570630 | ‖grad‖: 9.818e-02
# Epoch 16 | BCE Cost: 0.558655 | ‖grad‖: 7.703e-02
# Epoch 17 | BCE Cost: 0.549592 | ‖grad‖: 6.354e-02
# Epoch 18 | BCE Cost: 0.544409 | ‖grad‖: 6.996e-02
# Epoch 19 | BCE Cost: 0.542726 | ‖grad‖: 8.503e-02
# Epoch 20 | BCE Cost: 0.542889 | ‖grad‖: 9.653e-02
# Epoch 21 | BCE Cost: 0.543183 | ‖grad‖: 1.009e-01
# Epoch 22 | BCE Cost: 0.542684 | ‖grad‖: 9.813e-02
# Epoch 23 | BCE Cost: 0.541257 | ‖grad‖: 9.038e-02
# Epoch 33 | BCE Cost: 0.649265 | ‖grad‖: 1.146e-02
# Epoch 34 | BCE Cost: 0.649157 | ‖grad‖: 1.096e-02
# Epoch 35 | BCE Cost: 0.649033 | ‖grad‖: 1.097e-02
# Epoch 36 | BCE Cost: 0.648919 | ‖grad‖: 9.777e-03
# Epoch 37 | BCE Cost: 0.648816 | ‖grad‖: 7.143e-03
# Epoch 38 | BCE Cost: 0.648728 | ‖grad‖: 6.202e-03
# Epoch 39 | BCE Cost: 0.648668 | ‖grad‖: 1.011e-02
# Epoch 40 | BCE Cost: 0.648652 | ‖grad‖: 1.455e-02
# Epoch 41 | BCE Cost: 0.648660 | ‖grad‖: 1.641e-02
# Epoch 42 | BCE Cost: 0.648640 | ‖grad‖: 1.467e-02
# Epoch 43 | BCE Cost: 0.648565 | ‖grad‖: 1.002e-02
# Epoch 44 | BCE Cost: 0.648463 | ‖grad‖: 5.065e-03
# Epoch 45 | BCE Cost: 0.648390 | ‖grad‖: 5.089e-03
# Epoch 46 | BCE Cost: 0.648362 | ‖grad‖: 7.071e-03
# Epoch 47 | BCE Cost: 0.648351 | ‖grad‖: 6.633e-03
# Epoch 48 | BCE Cost: 0.648325 | ‖grad‖: 4.541e-03
# Epoch 49 | BCE Cost: 0.648288 | ‖grad‖: 4.932e-03
# Epoch 50 | BCE Cost: 0.648259 | ‖grad‖: 7.196e-03
# Epoch 51 | BCE Cost: 0.648230 | ‖grad‖: 7.548e-03
# Epoch 52 | BCE Cost: 0.648185 | ‖grad‖: 5.530e-03
# Epoch 53 | BCE Cost: 0.648132 | ‖grad‖: 3.553e-03
# Epoch 54 | BCE Cost: 0.648101 | ‖grad‖: 4.615e-03
# Epoch 55 | BCE Cost: 0.648096 | ‖grad‖: 5.425e-03
# Epoch 56 | BCE Cost: 0.648086 | ‖grad‖: 4.762e-03
# Epoch 57 | BCE Cost: 0.648055 | ‖grad‖: 4.855e-03
# Epoch 58 | BCE Cost: 0.648018 | ‖grad‖: 6.276e-03
# Epoch 59 | BCE Cost: 0.647992 | ‖grad‖: 6.437e-03
# Epoch 60 | BCE Cost: 0.647970 | ‖grad‖: 4.502e-03
# Epoch 61 | BCE Cost: 0.647944 | ‖grad‖: 2.474e-03
# Epoch 62 | BCE Cost: 0.647925 | ‖grad‖: 3.564e-03
# Epoch 63 | BCE Cost: 0.647914 | ‖grad‖: 4.075e-03
# Epoch 64 | BCE Cost: 0.647895 | ‖grad‖: 2.783e-03
# Epoch 65 | BCE Cost: 0.647866 | ‖grad‖: 2.626e-03
# Epoch 66 | BCE Cost: 0.647841 | ‖grad‖: 4.546e-03
# Epoch 67 | BCE Cost: 0.647828 | ‖grad‖: 5.224e-03
# Epoch 68 | BCE Cost: 0.647816 | ‖grad‖: 4.215e-03
# Epoch 69 | BCE Cost: 0.647798 | ‖grad‖: 2.939e-03
# Epoch 70 | BCE Cost: 0.647779 | ‖grad‖: 2.899e-03
# Epoch 71 | BCE Cost: 0.647762 | ‖grad‖: 2.803e-03
# Epoch 72 | BCE Cost: 0.647744 | ‖grad‖: 2.093e-03
# Epoch 73 | BCE Cost: 0.647727 | ‖grad‖: 2.388e-03
# Epoch 74 | BCE Cost: 0.647713 | ‖grad‖: 3.242e-03
# Epoch 75 | BCE Cost: 0.647702 | ‖grad‖: 3.144e-03
# Epoch 76 | BCE Cost: 0.647686 | ‖grad‖: 2.259e-03
# Epoch 77 | BCE Cost: 0.647668 | ‖grad‖: 1.957e-03
# Epoch 78 | BCE Cost: 0.647654 | ‖grad‖: 2.313e-03
# Epoch 79 | BCE Cost: 0.647643 | ‖grad‖: 2.282e-03
# Epoch 80 | BCE Cost: 0.647631 | ‖grad‖: 2.237e-03
# Epoch 81 | BCE Cost: 0.647617 | ‖grad‖: 2.534e-03
# Epoch 82 | BCE Cost: 0.647604 | ‖grad‖: 2.508e-03
# Epoch 83 | BCE Cost: 0.647591 | ‖grad‖: 2.015e-03
# Epoch 84 | BCE Cost: 0.647579 | ‖grad‖: 1.762e-03
# Epoch 85 | BCE Cost: 0.647568 | ‖grad‖: 1.834e-03
# Epoch 86 | BCE Cost: 0.647558 | ‖grad‖: 1.707e-03
# Epoch 87 | BCE Cost: 0.647546 | ‖grad‖: 1.768e-03
# Epoch 88 | BCE Cost: 0.647534 | ‖grad‖: 2.141e-03
# Epoch 89 | BCE Cost: 0.647525 | ‖grad‖: 2.188e-03
# Epoch 90 | BCE Cost: 0.647515 | ‖grad‖: 1.856e-03
# Epoch 91 | BCE Cost: 0.647505 | ‖grad‖: 1.664e-03
# Epoch 92 | BCE Cost: 0.647495 | ‖grad‖: 1.659e-03
# Epoch 93 | BCE Cost: 0.647486 | ‖grad‖: 1.553e-03
# Epoch 94 | BCE Cost: 0.647476 | ‖grad‖: 1.657e-03
# Epoch 95 | BCE Cost: 0.647468 | ‖grad‖: 1.942e-03
# Epoch 96 | BCE Cost: 0.647459 | ‖grad‖: 1.900e-03
# Epoch 97 | BCE Cost: 0.647451 | ‖grad‖: 1.583e-03
# Epoch 98 | BCE Cost: 0.647442 | ‖grad‖: 1.476e-03
# Epoch 99 | BCE Cost: 0.647434 | ‖grad‖: 1.522e-03
# Epoch 100 | BCE Cost: 0.647426 | ‖grad‖: 1.468e-03
# KCHOL.IS → QNN Test accuracy: 0.5849
# Epoch  1 | BCE Cost: 1.267874 | ‖grad‖: 9.108e-01
# Epoch  2 | BCE Cost: 1.171266 | ‖grad‖: 8.804e-01
# Epoch  3 | BCE Cost: 1.068964 | ‖grad‖: 7.810e-01
# Epoch  4 | BCE Cost: 0.975463 | ‖grad‖: 6.639e-01
# Epoch  5 | BCE Cost: 0.893169 | ‖grad‖: 5.429e-01
# Epoch  6 | BCE Cost: 0.822284 | ‖grad‖: 4.257e-01
# Epoch  7 | BCE Cost: 0.766506 | ‖grad‖: 3.186e-01
# Epoch  8 | BCE Cost: 0.725113 | ‖grad‖: 2.239e-01
# Epoch  9 | BCE Cost: 0.694898 | ‖grad‖: 1.487e-01
# Epoch 49 | BCE Cost: 0.540668 | ‖grad‖: 3.270e-02
# Epoch 50 | BCE Cost: 0.539709 | ‖grad‖: 3.331e-02
# Epoch 51 | BCE Cost: 0.538688 | ‖grad‖: 3.359e-02
# Epoch 52 | BCE Cost: 0.537570 | ‖grad‖: 3.250e-02
# Epoch 53 | BCE Cost: 0.536359 | ‖grad‖: 3.003e-02
# ...
# Epoch 85 | BCE Cost: 0.609735 | ‖grad‖: 8.338e-03
# Epoch 86 | BCE Cost: 0.609686 | ‖grad‖: 7.650e-03
# Epoch 87 | BCE Cost: 0.609636 | ‖grad‖: 7.408e-03
# Epoch 88 | BCE Cost: 0.609588 | ‖grad‖: 7.473e-03
# Epoch 89 | BCE Cost: 0.609543 | ‖grad‖: 7.363e-03
# Epoch 90 | BCE Cost: 0.609499 | ‖grad‖: 7.290e-03
# Epoch 91 | BCE Cost: 0.609457 | ‖grad‖: 7.532e-03
# Epoch 92 | BCE Cost: 0.609420 | ‖grad‖: 7.708e-03
# Epoch 93 | BCE Cost: 0.609384 | ‖grad‖: 7.502e-03
# Epoch 94 | BCE Cost: 0.609349 | ‖grad‖: 7.231e-03
# Epoch 95 | BCE Cost: 0.609313 | ‖grad‖: 7.213e-03
# Epoch 96 | BCE Cost: 0.609279 | ‖grad‖: 7.208e-03
# Epoch 97 | BCE Cost: 0.609243 | ‖grad‖: 7.001e-03
# Epoch 98 | BCE Cost: 0.609206 | ‖grad‖: 6.803e-03
# Epoch 99 | BCE Cost: 0.609169 | ‖grad‖: 6.744e-03
# Epoch 100 | BCE Cost: 0.609132 | ‖grad‖: 6.625e-03
# TUPRS.IS → QNN Test accuracy: 0.6108
# Epoch  1 | BCE Cost: 1.139540 | ‖grad‖: 1.050e+00
# Epoch  2 | BCE Cost: 1.028160 | ‖grad‖: 9.214e-01
# Epoch  3 | BCE Cost: 0.923597 | ‖grad‖: 7.532e-01
# Epoch  4 | BCE Cost: 0.837098 | ‖grad‖: 5.844e-01
# Epoch  5 | BCE Cost: 0.767174 | ‖grad‖: 4.285e-01
# Epoch  6 | BCE Cost: 0.712967 | ‖grad‖: 2.917e-01
# Epoch  7 | BCE Cost: 0.675735 | ‖grad‖: 1.817e-01
# Epoch  8 | BCE Cost: 0.652476 | ‖grad‖: 1.121e-01
# Epoch  9 | BCE Cost: 0.639036 | ‖grad‖: 1.162e-01
# Epoch 10 | BCE Cost: 0.632515 | ‖grad‖: 1.628e-01
# Epoch 11 | BCE Cost: 0.630169 | ‖grad‖: 2.034e-01
# Epoch 12 | BCE Cost: 0.629064 | ‖grad‖: 2.209e-01
# Epoch 13 | BCE Cost: 0.626666 | ‖grad‖: 2.088e-01
# Epoch 14 | BCE Cost: 0.621592 | ‖grad‖: 1.683e-01
# Epoch 15 | BCE Cost: 0.614680 | ‖grad‖: 1.161e-01
# Epoch 16 | BCE Cost: 0.608815 | ‖grad‖: 8.877e-02
# Epoch 17 | BCE Cost: 0.605643 | ‖grad‖: 8.818e-02
# Epoch 73 | BCE Cost: 0.523653 | ‖grad‖: 7.488e-03
# Epoch 74 | BCE Cost: 0.523430 | ‖grad‖: 7.183e-03
# Epoch 75 | BCE Cost: 0.523232 | ‖grad‖: 6.623e-03
# Epoch 76 | BCE Cost: 0.523059 | ‖grad‖: 6.107e-03
# Epoch 77 | BCE Cost: 0.522910 | ‖grad‖: 5.976e-03
# Epoch 78 | BCE Cost: 0.522781 | ‖grad‖: 6.214e-03
# Epoch 79 | BCE Cost: 0.522667 | ‖grad‖: 6.499e-03
# Epoch 80 | BCE Cost: 0.522560 | ‖grad‖: 6.590e-03
# Epoch 81 | BCE Cost: 0.522455 | ‖grad‖: 6.456e-03
# Epoch 82 | BCE Cost: 0.522351 | ‖grad‖: 6.182e-03
# Epoch 83 | BCE Cost: 0.522248 | ‖grad‖: 5.859e-03
# Epoch 84 | BCE Cost: 0.522146 | ‖grad‖: 5.549e-03
# Epoch 85 | BCE Cost: 0.522048 | ‖grad‖: 5.323e-03
# Epoch 86 | BCE Cost: 0.521953 | ‖grad‖: 5.252e-03
# Epoch 87 | BCE Cost: 0.521866 | ‖grad‖: 5.340e-03
# Epoch 88 | BCE Cost: 0.521787 | ‖grad‖: 5.497e-03
# Epoch 89 | BCE Cost: 0.521715 | ‖grad‖: 5.613e-03
# Epoch 90 | BCE Cost: 0.521648 | ‖grad‖: 5.648e-03
# Epoch 91 | BCE Cost: 0.521584 | ‖grad‖: 5.649e-03
# Epoch 92 | BCE Cost: 0.521524 | ‖grad‖: 5.683e-03
# Epoch 93 | BCE Cost: 0.521469 | ‖grad‖: 5.760e-03
# Epoch 94 | BCE Cost: 0.521419 | ‖grad‖: 5.820e-03
# Epoch 95 | BCE Cost: 0.521372 | ‖grad‖: 5.799e-03
# Epoch 96 | BCE Cost: 0.521329 | ‖grad‖: 5.672e-03
# Epoch 97 | BCE Cost: 0.521287 | ‖grad‖: 5.457e-03
# Epoch 98 | BCE Cost: 0.521249 | ‖grad‖: 5.180e-03
# Epoch 99 | BCE Cost: 0.521214 | ‖grad‖: 4.865e-03
# Epoch 100 | BCE Cost: 0.521182 | ‖grad‖: 4.540e-03
# VESTL.IS → QNN Test accuracy: 0.7358
# Epoch  1 | BCE Cost: 1.244300 | ‖grad‖: 7.431e-01
# Epoch  2 | BCE Cost: 1.167716 | ‖grad‖: 8.104e-01
# Epoch  3 | BCE Cost: 1.078065 | ‖grad‖: 7.705e-01
# Epoch  4 | BCE Cost: 0.986471 | ‖grad‖: 6.665e-01
# Epoch  5 | BCE Cost: 0.903356 | ‖grad‖: 5.456e-01
# Epoch  6 | BCE Cost: 0.831301 | ‖grad‖: 4.221e-01
# Epoch  7 | BCE Cost: 0.774637 | ‖grad‖: 3.097e-01
# Epoch  8 | BCE Cost: 0.733173 | ‖grad‖: 2.157e-01
# Epoch  9 | BCE Cost: 0.703641 | ‖grad‖: 1.510e-01
# Epoch 10 | BCE Cost: 0.684099 | ‖grad‖: 1.307e-01
# Epoch 11 | BCE Cost: 0.671891 | ‖grad‖: 1.440e-01
# Epoch 50 | BCE Cost: 0.529651 | ‖grad‖: 2.444e-02
# Epoch 51 | BCE Cost: 0.529608 | ‖grad‖: 2.958e-02
# Epoch 52 | BCE Cost: 0.529637 | ‖grad‖: 3.136e-02
# Epoch 53 | BCE Cost: 0.529615 | ‖grad‖: 2.972e-02
# Epoch 54 | BCE Cost: 0.529490 | ‖grad‖: 2.549e-02
# Epoch 55 | BCE Cost: 0.529279 | ‖grad‖: 2.010e-02
# Epoch 56 | BCE Cost: 0.529036 | ‖grad‖: 1.533e-02
# Epoch 57 | BCE Cost: 0.528814 | ‖grad‖: 1.291e-02
# Epoch 58 | BCE Cost: 0.528647 | ‖grad‖: 1.325e-02
# Epoch 59 | BCE Cost: 0.528547 | ‖grad‖: 1.489e-02
# Epoch 60 | BCE Cost: 0.528509 | ‖grad‖: 1.647e-02
# Epoch 61 | BCE Cost: 0.528510 | ‖grad‖: 1.735e-02
# Epoch 62 | BCE Cost: 0.528510 | ‖grad‖: 1.720e-02
# Epoch 63 | BCE Cost: 0.528464 | ‖grad‖: 1.593e-02
# Epoch 64 | BCE Cost: 0.528351 | ‖grad‖: 1.373e-02
# Epoch 65 | BCE Cost: 0.528181 | ‖grad‖: 1.111e-02
# Epoch 66 | BCE Cost: 0.527997 | ‖grad‖: 9.035e-03
# Epoch 67 | BCE Cost: 0.527848 | ‖grad‖: 8.604e-03
# Epoch 68 | BCE Cost: 0.527763 | ‖grad‖: 9.741e-03
# Epoch 69 | BCE Cost: 0.527736 | ‖grad‖: 1.126e-02
# Epoch 70 | BCE Cost: 0.527734 | ‖grad‖: 1.227e-02
# Epoch 71 | BCE Cost: 0.527719 | ‖grad‖: 1.243e-02
# Epoch 72 | BCE Cost: 0.527670 | ‖grad‖: 1.171e-02
# Epoch 73 | BCE Cost: 0.527589 | ‖grad‖: 1.024e-02
# Epoch 74 | BCE Cost: 0.527494 | ‖grad‖: 8.303e-03
# Epoch 75 | BCE Cost: 0.527408 | ‖grad‖: 6.584e-03
# Epoch 76 | BCE Cost: 0.527345 | ‖grad‖: 6.221e-03
# Epoch 77 | BCE Cost: 0.527306 | ‖grad‖: 7.455e-03
# Epoch 78 | BCE Cost: 0.527283 | ‖grad‖: 9.071e-03
# Epoch 79 | BCE Cost: 0.527261 | ‖grad‖: 1.005e-02
# Epoch 80 | BCE Cost: 0.527229 | ‖grad‖: 9.967e-03
# Epoch 81 | BCE Cost: 0.527183 | ‖grad‖: 8.819e-03
# Epoch 82 | BCE Cost: 0.527127 | ‖grad‖: 7.059e-03
# Epoch 83 | BCE Cost: 0.527073 | ‖grad‖: 5.638e-03
# Epoch 84 | BCE Cost: 0.527029 | ‖grad‖: 5.585e-03
# Epoch 85 | BCE Cost: 0.526998 | ‖grad‖: 6.508e-03
# Epoch 86 | BCE Cost: 0.526973 | ‖grad‖: 7.232e-03
# Epoch 87 | BCE Cost: 0.526945 | ‖grad‖: 7.185e-03
# Epoch 88 | BCE Cost: 0.526908 | ‖grad‖: 6.411e-03
# Epoch 89 | BCE Cost: 0.526865 | ‖grad‖: 5.415e-03
# Epoch 90 | BCE Cost: 0.526822 | ‖grad‖: 4.938e-03
# Epoch 91 | BCE Cost: 0.526788 | ‖grad‖: 5.241e-03
# Epoch 92 | BCE Cost: 0.526762 | ‖grad‖: 5.767e-03
# Epoch 93 | BCE Cost: 0.526740 | ‖grad‖: 5.961e-03
# Epoch 94 | BCE Cost: 0.526717 | ‖grad‖: 5.690e-03
# Epoch 95 | BCE Cost: 0.526688 | ‖grad‖: 5.158e-03
# Epoch 96 | BCE Cost: 0.526655 | ‖grad‖: 4.724e-03
# Epoch 97 | BCE Cost: 0.526620 | ‖grad‖: 4.612e-03
# Epoch 98 | BCE Cost: 0.526587 | ‖grad‖: 4.717e-03
# Epoch 99 | BCE Cost: 0.526558 | ‖grad‖: 4.800e-03
# Epoch 100 | BCE Cost: 0.526531 | ‖grad‖: 4.740e-03
# YKBNK.IS → QNN Test accuracy: 0.7123
#
# Average QNN Test Accuracy: 0.6697

# %% [markdown]
# ### Torch QNN with no classical preprocessing
#
# As stated before, we create a qnode using torch interface. Just train it using the above train pipeline. The results remain almost the same.

# %%
def make_pure_qnn_classifier(feature_dim, n_layers=6, lr=0.2, momentum=0.5):
    dev = qml.device("lightning.qubit", wires=feature_dim)

    @qml.qnode(dev, interface="torch")
    def qnode(inputs, weights):
        qml.AngleEmbedding(inputs, wires=range(feature_dim))
        qml.BasicEntanglerLayers(weights, wires=range(feature_dim))
        return qml.expval(qml.PauliZ(0))  # raw ∈ [-1,+1]

    weight_shapes = {"weights": (n_layers, feature_dim)}
    qlayer = qml.qnn.TorchLayer(qnode, weight_shapes)

    # Model is just the QLayer (output ∈[-1,1])
    model     = qlayer
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    loss_fn   = nn.MSELoss()  # between raw output and {-1,+1} labels

    return model, optimizer, loss_fn

# %% [markdown]
# ### Torch QNN with classical preprocessing
#
# This gives better result that just torch QNN - however, hybridQNN performs the best.

# %%
def make_pure_qnn_classifier(feature_dim, n_layers=6, lr=0.2, momentum=0.5):
    dev = qml.device("lightning.qubit", wires=feature_dim)

    # QNode now returns one PauliZ per wire
    @qml.qnode(dev, interface="torch")
    def qnode(inputs, weights):
        qml.AngleEmbedding(inputs, wires=range(feature_dim))
        qml.StronglyEntanglingLayers(weights, wires=range(feature_dim))
        return [qml.expval(qml.PauliZ(i)) for i in range(feature_dim)]

    weight_shapes = {"weights": (n_layers, feature_dim, 3)}
    qlayer = qml.qnn.TorchLayer(qnode, weight_shapes)

    class MultiQubitMSEClassifier(nn.Module):
        def __init__(self):
            super().__init__()
            self.qlayer = qlayer # collapse feature_dim quantum features → 1 output
            self.head = nn.Linear(feature_dim, 1)

        def forward(self, x):
            # x: [batch, feature_dim]
            exp_vals = self.qlayer(x)            # → [batch, feature_dim]
            out      = self.head(exp_vals).squeeze(-1)  
            return torch.sigmoid(out)               # → [batch]

    model    = MultiQubitMSEClassifier()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    loss_fn   = nn.MSELoss()                  # expects targets in [0, +1]

    return model, optimizer, loss_fn
